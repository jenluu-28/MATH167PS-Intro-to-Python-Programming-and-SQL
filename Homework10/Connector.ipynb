# %%
import mysql.connector
import pandas as pd

# %%
config2 = {
  'user': 'Jen',
  'password': 'oddSHRUB101@',
  'host': 'localhost',
  'database':"Sakila"
}
cnx = mysql.connector.connect(**config2) 
cursor = cnx.cursor()


cursor.execute("""DESC rental""")              # get details of table "departments"
row = cursor.fetchone()


colnames = []
while row is not None:                              # make vector of variable names (column names)
    colnames.append(row[0])
    row = cursor.fetchone()
    
cursor.execute("""SELECT * FROM rental""")     # get all data from departments table
results = cursor.fetchall()

cursor.close()                                      
cnx.close()                                         # disconnect

pd.DataFrame(results, columns = colnames)           # make Pandas data frame and label columns appropriately
# Out:
#        rental_id         rental_date  inventory_id  customer_id  \
# 0              1 2005-05-24 22:53:30           367          130
# 1              2 2005-05-24 22:54:33          1525          459
# 2              3 2005-05-24 23:03:39          1711          408
# 3              4 2005-05-24 23:04:41          2452          333
# 4              5 2005-05-24 23:05:21          2079          222
# ...          ...                 ...           ...          ...
# 16039      16045 2005-08-23 22:25:26           772           14
# 16040      16046 2005-08-23 22:26:47          4364           74
# 16041      16047 2005-08-23 22:42:48          2088          114
# 16042      16048 2005-08-23 22:43:07          2019          103
# 16043      16049 2005-08-23 22:50:12          2666          393
#
#               return_date  staff_id         last_update
# 0     2005-05-26 22:04:30         1 2006-02-15 21:30:53
# 1     2005-05-28 19:40:33         1 2006-02-15 21:30:53
# ...
